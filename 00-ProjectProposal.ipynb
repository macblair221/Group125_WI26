# %% [markdown]
# # COGS 108 - Project Proposal
#
# ## Authors

# %% [markdown]
# - Sarah Flores
# - Kaylin Chan
# - Mcallister Blair
# - Emery Wang
# - Mariarosa Cerritos Lara

# %% [markdown]
# ## Research Question

# %% [markdown]
# How does emotional intensity correlate with the way people recall and describe personal events? Can a difference be observed between different age groups?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Emotion has a significant impact on cognitive processes in humans, including attention, learning, and memory. <a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) The amygdala is a brain structure located in the temporal lobe, and it is responsible for processing emotions, such as fear, anger, and anxiety. The hippocampal complex is also located in the temporal lobe, and it is responsible for memory encoding.
#
# A previous study has revealed how the amygdala and the hippocampal complex work together when forming emotional memories. <a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) While the two brain structures are linked to two independent memory systems, the amygdala has shown to have influence on the encoding and storage of memories dependent on the hippocampal complex. The ability to attend to a stimulus is a primary factor in how well the stimulus is encoded. Since the amygdala responds to emotional stimuli rapidly, emotional events can receive priority when memories are encoded. Additionally, when memories are consolidated, events that elicit emotional responses are more likely to be remembered for later.
#
# In a study that experimented with autobiographical memories that varied in valence (positive or negative) and intensity (high or low), it was found that the emotional intensity affects the properties of autobiographical memories more than valence. <a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3) The study concluded that highly intense events tend to be remembered longer and with greater vividness.
#
# Another study has also found that a perspective change from a field (first-person) to an observer (third-person) reduces the emotional intensity of recalled events. <a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4) Given the study above, a field-to-observer perspective change is likely to reduce the vividness of a memory. Additionally, the study indicates that the autobiographical memory system has plasticity, and a perspective change alters the autobiographical records of recalled events.
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Tyng, Chai M et al. “The Influences of Emotion on Learning and Memory.” Frontiers in psychology vol. 8 1454. 24 Aug. 2017, doi:10.3389/fpsyg.2017.01454
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Phelps, Elizabeth A. “Human Emotion and Memory: Interactions of the Amygdala and Hippocampal Complex.” Current Opinion in Neurobiology, vol. 14, no. 2, 2004, pp. 198–202. Current Opinion in Neurobiology, doi:10.1016/j.conb.2004.03.015.
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Talarico, J.M., LaBar, K.S. & Rubin, D.C. Emotional intensity predicts autobiographical memory experience. Memory & Cognition 32, 1118–1132 (2004). https://doi.org/10.3758/BF03196886.
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) Sekiguchi, Tatsuya, and Shogo Nonaka. “The Long-Term Effect of Perspective Change on the Emotional Intensity of Autobiographical Memories.” Cognition and Emotion, vol. 28, no. 2, 2014, pp. 375–383, doi:10.1080/02699931.2013.825233.

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We predict that while high emotional intensity will increase the vividness and detail of personal memories across all age groups, older adults will report significantly higher emotional intensity for events involving poignancy compared to younger adults, leading to a more frequent use of a first-person perspective and greater sensory detail in their descriptions of these specific events.
#
# We believe this because emotional intensity acts as a primary driver for memory since the brain’s emotional processing centers prioritize high-arousal events for deep storage, making them significantly more vivid than neutral experiences. This intensity maintains a first-person perspective during recall, which prevents the memory from becoming detached and preserves its sensory richness within the autobiographical record. Therefore, while this biological process is believed to be universal amongst all ages, we have hypothesized that older adults are able to recall greater detail in certain memories because their cognitive focus shifts toward greater emotional meaning, triggering a more intense recording of those specific events compared to younger age groups that are recorded to have different intensities.

# %% [markdown]
# ## Data

# %% [markdown]
# An idea dataset to answer this question would have variables regarding demographic information (such as age and gender) of participants, time taken to recall memories, emotional intensity of said memory when recalling, memory content (to measure poignancy/significance and clarity/vividness of events, and memory perspective (first person or third person). To achieve statistical power for analysis of how age may influence the intensity of memory and how that may affect memory clarity and perspective, an ideal dataset would need a random sample of around 400-500 observations with at least 200-300 in the older bracket and 300 in the younger for variance. This data would be collected through online/in-person surveys and designed studies where participants are tasked with recalling certain prompted events. The results would then be recorded  via a standardized rating scale for our variables (i.e. intensity, emotional attachment), as well as an account of the story’s events. The data should be stored in a CSV format or in a relational database (trustworthy & open source), with tables containing individual event ratings on a standardized scale, demographics, and so forth for variable modeling and analysis.
#
# 1. Simply put to answer the hypothesis, we need the following data:
#     1. Demographic information (such as age and gender) of surveyed participants
#     2. Time taken to recall memories and emotional intensity of said memory when recalling it
#     3. Memory content (to measure poignancy/significance and clarity/vividness of events)
#     4. Memory perspective (first person, third, etc.)
#
# 2.  To achieve statistical power for analysis of how age may influence the intensity of memory and how that may affect memory clarity and perspective, we need a random sample of at least 400 observations with at least 200 in the older bracket and 200 in the younger for variance.
#
# 3. Data collection can be done through online or in-person surveys and designed studies where participants are tasked with recalling certain prompted events, and then record the results via a standardized rating scale for our variables (i.e. intensity, emotional attachment), as well as an account of the story’s events.
#
# 4. The data should be stored in a CSV format or in a relational database (trustworthy & open source), with tables containing individual event ratings on a standardized scale, demographics, and so forth for variable modeling and analysis.
#
# 5. We have found 3 potential datasets we can utilize to answer our research question:
#     1. [This dataset](https://www.kaggle.com/datasets/saurabhshahane/hippocorpus?select=hippoCorpusV2.csv) is easily accessible through kaggle and we are allowed to download it with no issue. The study had participants recall stories either imagined or lived. The dataset consists of 23 columns but the ones we might use for this project are age, time since event, importance, similarity, draining, memtype, and stress. We selected these variables so that we can clean and account for potential confounding variables.
#     2. [This dataset](https://ssh.datastations.nl/dataset.xhtml?persistentId=doi:10.17026/SS/6EGKHT
# ) is made publicly available to download at DANS Data Station Social Sciences and Humanities. This research spans 17 participants recalling happy and sad memories and rating the past and present valence of memories. Important variables include gender, cueword, emotional memory duration, past valence rating, present valence rating, and sentiment.
#     3. [This dataset](https://figshare.com/articles/dataset/The_Cue-Recalled_Autobiographical_Memory_Test_DATASET/10246958?file=19556471) was made publicly available through figshare. The CRAM/SPAM study collected autobiographical memories using word cues and had participants describe memories and count details across categories like People, Places, Feelings, etc. Important variables include age, gender, how old the memory was, and the score of details in the memory across emotions.

# %% [markdown]
# ## Ethics
#
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# > The dataset we are using was made using a crowdsourcing framework, which may introduce bias, such as language proficiency, cultural differences, and self-selection. These limitations are acknowledged, and predictions will be made with them in mind. The dataset is de-identified and does not contain direct personally identifiable information such as names or contact information; no new information is added, and the variables we will use are only relevant to the research question. The dataset includes demographic information, so we will be able to see if a particular group favors some outcome. These attributes are used only for bias assessment and not as prediction features.
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# > The Hippocorpus dataset, which we will be using in our project, is publicly available and de-identified, stripped of all personally identifiable information, and does not collect new data. The dataset is publicly available through Kaggle and maintained by a third party. For this project, local copies of the data will be retained only for the duration of the assignment and will be deleted once the project is completed. The data will not be reused or stored long-term beyond the time of this course.
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# > Yes, we will address blind spots in our analysis. We already noted that since this dataset was created using a crowdsourcing framework, it could favor a particular demographic, creating blind spots for other groups. We have acknowledged this and will move forward knowing that we may not be able to generalize our findings across all demographics. Our visualizations and summary statistics will be made with the data collection process in mind as well, only making conclusions about a certain group of people or excluding features in our predictions that may introduce bias. Yes, we have ensured the data we are using does not contain any direct PII like names and any kind of contact info. The data we are using is de-identified and does not collect any new patient data. The process of our analysis will follow a common data science project end-to-end pipeline, with every change recorded in a GitHub workflow, documenting our entire process so we can refer back to previous versions or test different models on our dataset.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# > The dataset includes demographic variables such as race, gender, and age, which are sensitive attributes. These variables will not be used as prediction features but will instead be used only to evaluate fairness across groups. We also recognize that some non-demographic variables, such as time to complete the task or emotional ratings, could act as indirect proxy variables for demographic characteristics. Because of this, we will monitor model outcomes across demographic groups. We found that ~73% of the people in the dataset are White, ~10% are Black, ~5% Hispanic, ~2% asian, and the remaining is split between other races such as API, Native, and Middle Eastern. We have also noted that ~60% of the dataset are people aged 25-39. Between genders, the dataset is split almost perfectly 50% man, 50% woman, but it's more like 49%-49% with a few non-binary/transgender identifying individuals.
# >
# > When optimizing for our defined metrics, we have noted that some of our features are quantitative ordinal values (1-5) describing different kinds of reported cognitive load. Dealing with these kinds of values in data analysis can be difficult, but we have noted that we can use imputation techniques for missing values and can utilize methods such as mean, median, mode, and even probabilistic imputation if needed. As noted above, we have recognized possible limitations and biases that may be present in our study within certain demographics and the overall population.
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# > Although our model will only be created for the intended 'Hippocorpus' dataset, and is not designed to work across other datasets, we do have the ability to roll back or turn off the model if it is necessary. Since our model is designed for a dataset where no new values are added, the performance should remain constant over time, but it will be monitored if it's intended for future use.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# Emery Wang,
# Kaylin Chan,
# Sarah Flores,
# Mcallister Blair,
# Mariarosa Cerritos Lara
#
# * *Team Expectation 1: When we make decisions about the project, it will be unanimous among group members.*
# * *Team Expectation 2: Weekly meetings will be held in-person & under 30 minutes to respect eachothers' time (unless necessary and otherwise stated).*
# * *Team Expecation 3: Maintain clean, polite, and timely communication with the team via iMessage group chat.*
# * *Team Expectation 4: Check group chat before pushing to avoid merge conflicts.*
# * *Team Expectation 5: Make it a habit to edit on the shared Google document before updating Git/Jupyter.*
# * *Team Expectation 6: Notify Groupchat if you find yourself having trouble completing your work atleast 24 hours before the due date.*

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 2/2  |  5 PM | Conduct deep dive into topic ideas, sources, and potential data sets. Figure out meeting times and dates  | Determine the best form of communication. Ensure group access to Git. Discuss and decide on the final project topic; divide up sections of work. Divide sections of the proposal |
# | 2/9  |  5 PM |  Complete project proposal parts and review as a whole. Begin defining topic definitions, finalizing variable lists, and do a shallow dive into data sources. | Discuss wrangling data and analytical approaches, notes about the data sources, and any outliers, noise, missing info, and such. Decide upon next steps and delegate tasks |
# | 2/16  | 5 PM  | Import and wrangle data again, run core analysis on correlations between variables  | Discuss insights after data extraction. Determine if data supports hypothesis and next steps of visualization and analysis   |
# | 2/23  | 5 PM  | Finalize collection and wrangling. Deepen analysis based on meeting feedback. Begin brainstorming visualization | Review/Edit wrangling/EDA; Discuss Analysis Plan   |
# | 3/2  | 5 PM  | Create plots, graphs, and such. Draft methods and results sections of the final project |Discuss progress on divided parts, and delegate next steps once more |
# | 3/13  | 5 PM  | Complete analysis; Draft results/conclusion/discussion (Wasp)| Discuss/edit full project |
# | 3/20  | Before 11:59 PM  | NA | Turn in Final Project & Group Project Surveys |
